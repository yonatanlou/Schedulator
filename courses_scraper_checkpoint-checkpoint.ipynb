# %%
# set options to be headless, ..
from selenium import webdriver


import re

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from time import sleep
from selenium import webdriver
from selenium.webdriver.support.ui import Select

#installation guide for selenium
#https://medium.com/@shanyitan/how-to-install-selenium-and-run-it-successfully-via-jupyter-lab-c3f50d22a0d4

# %%
#gathering information function
def gather(browser):
    lst=[]
    try:
        x=1
        while True: 
            x_pather = "//*[@id='myBody']/table/tbody/tr/td/table/tbody/tr[5]/td/form/table/tbody/tr[3]/td/a["+str(x)+"]"
            main = browser.find_element_by_xpath(x_pather)
            x+=1
            lst.append(main)
    except:
        lst.pop()
    return lst

# %% [markdown]
# ### Scraping the data with selenium
# *TODO we need to make it run by page
#
# *TODO testing with other maslulim (Economics and statistics is good but computers not)

# %%
browser = webdriver.Chrome()
browser.get("https://shnaton.huji.ac.il/")






select = Select(browser.find_element_by_id('faculty'))
#select.select_by_value('12') #Pass value as string
select.select_by_value('07') #Pass value as string
sleep(1)

select = Select(browser.find_element_by_id('hugim'))
#select.select_by_value('0521')
select.select_by_value('0824')
sleep(1)

select = Select(browser.find_element_by_id('maslul'))
#select.select_by_value('3011')
select.select_by_value('7411')
sleep(1)

select = Select(browser.find_element_by_id('toar'))
select.select_by_value('1')
sleep(1)

select = Select(browser.find_element_by_id('shana'))
select.select_by_value('0')
sleep(1)

browser.find_element_by_css_selector("input[type='radio'][id='full']").click()
sleep(0.2)

browser.find_element_by_css_selector("input[type='button'][value=' חפש ']").click()

#collecting information
#TODO - make it work for more than 2 pages
try:
    while True:#information gathering function here
        browser.execute_script("window.scrollTo(0,document.body.scrollHeight)")
        sleep(2.5)
        lst=gather(browser)
        browser.find_element_by_xpath("//a[@title='העמוד הבא']").click()
except:
    print(lst)
    browser.close
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="74f565dadf4fd5412c992e3f905083a6", element="84c9dc49-0123-4b22-9e10-928612550d07")>, <selenium.webdriver.remote.webelement.WebElement (session="74f565dadf4fd5412c992e3f905083a6", element="b8624148-71db-43c0-a0f3-335d3c41cb55")>, <selenium.webdriver.remote.webelement.WebElement (session="74f565dadf4fd5412c992e3f905083a6", element="9cb907bf-2ed9-4b9f-90c6-408b4d7e6366")>, <selenium.webdriver.remote.webelement.WebElement (session="74f565dadf4fd5412c992e3f905083a6", element="2bd07be3-4ebc-4b3c-86ec-f2ce127e4cca")>, <selenium.webdriver.remote.webelement.WebElement (session="74f565dadf4fd5412c992e3f905083a6", element="febc8c01-3311-4745-be14-b41fbdea66b0")>, <selenium.webdriver.remote.webelement.WebElement (session="74f565dadf4fd5412c992e3f905083a6", element="08588d25-3fce-422c-98bd-fe3df67bf7d4")>, <selenium.webdriver.remote.webelement.WebElement (session="74f565dadf4fd5412c992e3f905083a6", element="4cf41ae5-6251-499f-b050-ac444ec3d844")>, <selenium.webdriver.remote.webelement.WebElement (session="74f565dadf4fd5412c992e3f905083a6", element="2890c861-2546-45b8-95cd-fffead9ddcd3")>, <selenium.webdriver.remote.webelement.WebElement (session="74f565dadf4fd5412c992e3f905083a6", element="fa7cf55c-b487-4bff-afcb-ad418c8a63a3")>, <selenium.webdriver.remote.webelement.WebElement (session="74f565dadf4fd5412c992e3f905083a6", element="7be97435-e4df-4db1-969f-0ae13833e7d1")>, <selenium.webdriver.remote.webelement.WebElement (session="74f565dadf4fd5412c992e3f905083a6", element="e10200e9-326b-4e2e-b425-939f781153b4")>, <selenium.webdriver.remote.webelement.WebElement (session="74f565dadf4fd5412c992e3f905083a6", element="f4836883-6ac6-48b6-890d-217935c3eb27")>, <selenium.webdriver.remote.webelement.WebElement (session="74f565dadf4fd5412c992e3f905083a6", element="cf83f557-c1f8-44ab-ae34-8027f542b881")>, <selenium.webdriver.remote.webelement.WebElement (session="74f565dadf4fd5412c992e3f905083a6", element="8a97a199-0e15-4818-82bc-1d5b31d20b83")>, <selenium.webdriver.remote.webelement.WebElement (session="74f565dadf4fd5412c992e3f905083a6", element="c67ba1ee-f4b9-4e92-8a31-2eeef106eea2")>, <selenium.webdriver.remote.webelement.WebElement (session="74f565dadf4fd5412c992e3f905083a6", element="ac7a13e7-ea91-4fc3-8357-fd17ef4ea1d8")>, <selenium.webdriver.remote.webelement.WebElement (session="74f565dadf4fd5412c992e3f905083a6", element="dfcb67fc-58b9-406d-b044-f29f79b01e1e")>, <selenium.webdriver.remote.webelement.WebElement (session="74f565dadf4fd5412c992e3f905083a6", element="2e41b0f2-adec-42e7-9119-292e2c2204b8")>, <selenium.webdriver.remote.webelement.WebElement (session="74f565dadf4fd5412c992e3f905083a6", element="4a0ff9cd-0217-4772-a3a8-231fa8534da9")>, <selenium.webdriver.remote.webelement.WebElement (session="74f565dadf4fd5412c992e3f905083a6", element="c970da20-1b1c-49fa-974f-2c96b251c8e5")>, <selenium.webdriver.remote.webelement.WebElement (session="74f565dadf4fd5412c992e3f905083a6", element="7c10e355-94d9-4cac-bb67-06efe7a6432d")>, <selenium.webdriver.remote.webelement.WebElement (session="74f565dadf4fd5412c992e3f905083a6", element="3afe551a-dc16-445e-8f21-cd179969f4f1")>, <selenium.webdriver.remote.webelement.WebElement (session="74f565dadf4fd5412c992e3f905083a6", element="8df0e9ca-0ca1-4c37-8c0f-c99bea1944c2")>, <selenium.webdriver.remote.webelement.WebElement (session="74f565dadf4fd5412c992e3f905083a6", element="fdae2ff2-6017-425d-a65b-1e180070673c")>, <selenium.webdriver.remote.webelement.WebElement (session="74f565dadf4fd5412c992e3f905083a6", element="77e55d4e-f117-4556-8fbb-1e8c003ed1ce")>, <selenium.webdriver.remote.webelement.WebElement (session="74f565dadf4fd5412c992e3f905083a6", element="b7425799-03fd-4b5c-82b9-0e1710463da7")>, <selenium.webdriver.remote.webelement.WebElement (session="74f565dadf4fd5412c992e3f905083a6", element="a9e93514-edae-42c8-b9a4-6c757662d7d5")>, <selenium.webdriver.remote.webelement.WebElement (session="74f565dadf4fd5412c992e3f905083a6", element="14d212c3 ...

# %%
scraped_data = [i.text for i in lst]

# %% [markdown]
# ### Gathering the data from the scrpaed text
# gathering the data to dictionaries with regex.
# we might have some weak points here.
# #TODO test with other maslulim.
#
# #### infrastructure
# database = {id:["semester": א\ב\שנתי, "day": א\ב\ג\ד\ה\ו, "hours": "hh:mm-hh:mm",....,..]}
#
# from outside to inside:
# big dictionary keys are for course_id, the value is a list which every item in the list is a different hour of the class.

# %%
def data_gatherer(scraped_data):
    """ Return (dictionary that contains all the courses per page, canceled courses)"""
    database = dict()
    canceled_courses = []
    for course in scraped_data:
        course_details = []
        info_by_day = dict()


        hours = (re.findall(r"([0-5][0-9]:[0-5][0-9]-[0-5][0-9]:[0-5][0-9])", course))
        course_id = (re.findall(r"\|\s{3}(\d{5})", course))
        day = (re.findall(r"\n(יום [אבגדהו])", course))
        semester = (re.findall(r"\n(שנתי|סמסטר [אבגדהו])", course))
  
        #checking for canceled courses
        if len(course_id) == 0 or len(hours) == 0:
            if len(hours) == 0:
                canceled_courses.append(course_id)
            pass

        else:
            for item in range(len(hours)):
                try:
                    info_by_day["semester"] = semester[item] 
                    info_by_day["day"] = day[item]
                    info_by_day["hours"] = hours[item]
                except:
                    print(course) 
                course_details.append(info_by_day)

            database[course_id[0]] = course_details

    canceled_courses = [x for x in canceled_courses if x != []]
    return database, canceled_courses
data_gatherer(scraped_data)
# Out:
# ({'57676': [{'semester': 'סמסטר ב', 'day': 'יום ד', 'hours': '10:15-08:30'},
#    {'semester': 'סמסטר ב', 'day': 'יום ד', 'hours': '10:15-08:30'}],
#   '57257': [{'semester': 'סמסטר ב', 'day': 'יום ב', 'hours': '12:15-08:30'}],
#   '57255': [{'semester': 'סמסטר א', 'day': 'יום ה', 'hours': '10:15-08:30'},
#    {'semester': 'סמסטר א', 'day': 'יום ה', 'hours': '10:15-08:30'}],
#   '57643': [{'semester': 'שנתי', 'day': 'יום ה', 'hours': '14:15-12:30'}],
#   '57639': [{'semester': 'סמסטר ב', 'day': 'יום ד', 'hours': '18:15-16:30'},
#    {'semester': 'סמסטר ב', 'day': 'יום ד', 'hours': '18:15-16:30'}],
#   '57736': [{'semester': 'שנתי', 'day': 'יום ה', 'hours': '10:15-08:30'}],
#   '57152': [{'semester': 'סמסטר א', 'day': 'יום ד', 'hours': '16:15-14:30'},
#    {'semester': 'סמסטר א', 'day': 'יום ד', 'hours': '16:15-14:30'}],
#   '57811': [{'semester': 'סמסטר א', 'day': 'יום ה', 'hours': '16:15-14:30'},
#    {'semester': 'סמסטר א', 'day': 'יום ה', 'hours': '16:15-14:30'}],
#   '57200': [{'semester': 'שנתי', 'day': 'יום א', 'hours': '18:15-16:30'}],
#   '57128': [{'semester': 'סמסטר א', 'day': 'יום ד', 'hours': '18:15-16:30'},
#    {'semester': 'סמסטר א', 'day': 'יום ד', 'hours': '18:15-16:30'}],
#   '57469': [{'semester': 'שנתי', 'day': 'יום א', 'hours': '14:15-12:30'}],
#   '57900': [{'semester': 'סמסטר ב', 'day': 'יום ב', 'hours': '10:15-08:30'},
#    {'semester': 'סמסטר ב', 'day': 'יום ב', 'hours': '10:15-08:30'}],
#   '57401': [{'semester': 'שנתי', 'day': 'יום ג', 'hours': '16:15-14:30'}],
#   '52542': [{'semester': 'סמסטר א', 'day': 'יום ד', 'hours': '14:15-11:30'}],
#   '52755': [{'semester': 'סמסטר א', 'day': 'יום ב', 'hours': '19:45-17:00'}],
#   '52700': [{'semester': 'סמסטר ב', 'day': 'יום ד', 'hours': '16:15-13:30'}],
#   '52710': [{'semester': 'סמסטר ב', 'day': 'יום ג', 'hours': '11:15-08:30'}],
#   '52747': [{'semester': 'סמסטר ב', 'day': 'יום א', 'hours': '19:15-16:30'}],
#   '52640': [{'semester': 'סמסטר א', 'day': 'יום ג', 'hours': '16:15-13:30'}],
#   '57556': [{'semester': 'סמסטר ב', 'day': 'יום ג', 'hours': '13:15-10:30'}],
#   '57830': [{'semester': 'סמסטר ב', 'day': 'יום ד', 'hours': '18:15-16:30'},
#    {'semester': 'סמסטר ב', 'day': 'יום ד', 'hours': '18:15-16:30'}],
#   '57973': [{'semester': 'סמסטר א', 'day': 'יום א', 'hours': '19:15-16:30'}],
#   '55803': [{'semester': 'סמסטר ב', 'day': 'יום ג', 'hours': '20:15-19:30'},
#    {'semester': 'סמסטר ב', 'day': 'יום ג', 'hours': '20:15-19:30'},
#    {'semester': 'סמסטר ב', 'day': 'יום ג', 'hours': '20:15-19:30'},
#    {'semester': 'סמסטר ב', 'day': 'יום ג', 'hours': '20:15-19:30'},
#    {'semester': 'סמסטר ב', 'day': 'יום ג', 'hours': '20:15-19:30'},
#    {'semester': 'סמסטר ב', 'day': 'יום ג', 'hours': '20:15-19:30'},
#    {'semester': 'סמסטר ב', 'day': 'יום ג', 'hours': '20:15-19:30'},
#    {'semester': 'סמסטר ב', 'day': 'יום ג', 'hours': '20:15-19:30'}]},
#  [['57256'], ['57670'], ['57642'], ['57132']])

# %%
#helper for regex
counter = 0
for i in scraped_data:
    print(counter)
    print(i,"\n"+"\n"+"*******end of object********"+"\n"+"\n")
    counter += 1
# Out:
# 0
#
#
# *******end of object********
#
#
# 1
#
#
# *******end of object********
#
#
# 2
# הפקולטה למדעי החברה :כלכלה
# Exchange Rates and International Macroeconomics שערי חליפין ומאקרו-כלכלה בין-לאומית   |   57676
# עבודה בכתב 2 ש"ש 4 נ"ז סמסטר ב'
#       תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
# 1706 חבר (הר הצופים)
# 1706 חבר (הר הצופים)
#
#
# 18:45-17:00
# 10:15-08:30
# יום ב'
# יום ד'
# סמסטר ב
# סמסטר ב
# (א) שעור ד"ר רפאל פרנק
# הערה:
# אופי הבחינה/המטלה הסופית עשוי להשתנות בהתאם להחלטות אוניברסיטאיות פקולטטיות לרגל המצב. דרישה מוקדמת: ציון עובר בקורסים מחירים א', מאקרו א' ומבוא לאקונומטריקה.
# Comments:
#
# *******end of object********
#
#
# 3
# הפקולטה למדעי החברה :כלכלה
# Labor Econmics כלכלת עבודה
# הקורס אינו מתקיים השנה   |   57256
# משך הבחינה: 2.50 ש' בחינה בכתב 2 ש"ש 4 נ"ז סמסטר א'
#       תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
#
# *******end of object********
#
#
# 4
# הפקולטה למדעי החברה :כלכלה
# International Trade and Development מסחר בינלאומי ופיתוח   |   57257
# עבודה בכתב 2 ש"ש 4 נ"ז סמסטר ב' נלמד באנגלית
#       תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
# 1711 חבר (הר הצופים)
#
# 12:15-08:30
# יום ב'
# סמסטר ב
# (א) שעור ד"ר איב סירה
# הערה:
#   Comments:
#
#
# *******end of object********
#
#
# 5
# הפקולטה למדעי החברה :כלכלה
# Regulation, Antitrust and the Theory of the Firm פיקוח, הגבלים עסקיים ותורת הפירמה
# הקורס אינו מתקיים השנה   |   57670
# משך הבחינה: 2.50 ש' בחינה בכתב 2 ש"ש 4 נ"ז סמסטר ב'
# דרישות קדם     תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
#
#
# . קורסי חקר - מיועדים לתלמידי שנה ג' במחלקה לכלכלה. יש לבחור אחד מבין הקורסים הבאים, ולכתוב במסגרתו עבודת חקר
#
# *******end of object********
#
#
# 6
# הפקולטה למדעי החברה :כלכלה
# Topics in Market Design נושאים בעיצוב שווקים   |   57255
# עבודה בכתב 2 ש"ש 4 נ"ז סמסטר א'
#       תכניות לימודים   סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
#
#
#
#
# 10:15-08:30
# 10:15-08:30
# יום ג'
# יום ה'
# סמסטר א
# סמסטר א
# (א) שעור ד"ר אסף רום
# הערה:
# דרישות קדם: מחירים ב'
# Comments:
#
# *******end of object********
#
#
# 7
# הפקולטה למדעי החברה :כלכלה
# Topics in Applied Microeconomics נושאים במיקרו-כלכלה יישומית   |   57643
# עבודה בכתב 2 ש"ש 4 נ"ז שנתי
# דרישות קדם     תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
#
#
# 14:15-12:30
# יום ה'
# שנתי
# (א) שעור פרופ אסף זוסמן
# הערה:
# דרישה מוקדמת: ציון עובר ב'מבוא לאקונומטריקה' (57322).
# Comments:
#
# *******end of object********
#
#
# 8
# הפקולטה למדעי החברה :כלכלה
# Research Course in Applied Economics כלכלה יישומית   |   57639
# עבודה בכתב 2 ש"ש 4 נ"ז סמסטר ב' נלמד באנגלית
# דרישות קדם     תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
# 3202 חבר (הר הצופים)
# 3202 חבר (הר הצופים)
#
#
# 18:45-17:00
# 18:15-16:30
# יום ב'
# יום ד'
# סמסטר ב
# סמסטר ב
# (א) שעור ד"ר נעמי האוזמן
# הערה:
# ההרצאות יינתנו באנגלית; את העבודות ניתן לכתוב באנגלית או בעברית. דרישה מוקדמת: ציון עובר בקורסים 'תורת המחירים א' וב' (57307, 57308) ו'מבוא לאקונומטריקה' (57322).
# Comments:
#
# *******end of object********
#
#
# 9
# הפקולטה למדעי החברה :כלכלה
# TOPICS IN POLITICAL ECONOMY נושאים בכלכלה פוליטית   |   57736
# עבודה בכתב 2 ש"ש 4 נ"ז שנתי
#       תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
#
#
# 10:15-08:30
# יום ה'
# שנתי
# (א) שעור פרופ אסטבן קלור
# הערה:
# דרישה מוקדמת: מבוא לאקונומטריקה (57322).
# Comments:
#
# *******end of object********
#
#
# 10
# הפקולטה למדעי החברה :כלכלה
# Topics in Empirical Microeconomics נושאים במיקרו כלכלה אמפירית   |   57152
# עבודה בכתב 2 ש"ש 4 נ"ז סמסטר א'
# דרישות קדם     תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
#
#
#
#
# 16:45-15:00
# 16:15-14:30
# יום ב'
# יום ד'
# סמסטר א
# סמסטר א
# (א) שעור פרופ שאול לאך
# הערה:
# דרישה מוקדמת: ציון עובר במבוא לאקונומטריקה (57322).
# Comments:
# Prerequisite: Passing grade in Introduction to Econometrics (57322).
#
# *******end of object********
#
#
# 11
# הפקולטה למדעי החברה :כלכלה
# The Economics of Migration כלכלת הגירה   |   57811
# עבודה בכתב 2 ש"ש 4 נ"ז סמסטר א' נלמד באנגלית
#       תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
#
#
#
#
# 16:15-14:30
# 16:15-14:30
# יום א'
# יום ה'
# סמסטר א
# סמסטר א
# (א) שעור ד"ר מיכאל עמיאור
# הערה:
# תנאי קדם: ציון עובר בקורס מבוא לאקונומטריקה
# Comments:
#
# *******end of object********
#
#
# 12
# הפקולטה למדעי החברה :כלכלה
# Topics in Game Theory נושאים בתורת המשחקים   |   57200
# עבודה בכתב 2 ש"ש 4 נ"ז שנתי נלמד באנגלית
#       תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
#
#
# 18:15-16:30
# יום א'
# שנתי
# (א) שעור פרופ אירנה ולסקי
# הערה:
#   Comments:
#
#
# *******end of object********
#
#
# 13
# הפקולטה למדעי החברה :כלכלה
# Selected Topics in Behavioral Economics סוגיות נבחרות בכלכלה התנהגותית   |   57128
# עבודה בכתב 2 ש"ש 4 נ"ז סמסטר א'
#       תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
#
#
#
#
# 18:45-17:00
# 18:15-16:30
# יום ב'
# יום ד'
# סמסטר א
# סמסטר א
# (א) שעור פרופ אייל וינטר
# הערה:
#   Comments:
#
#
# *******end of object********
#
#
# 14
# הפקולטה למדעי החברה :כלכלה
# Topics in Empirical Tax Research נושאים בחקר המיסוי אמפירי   |   57469
# עבודה בכתב 2 ש"ש 4 נ"ז שנתי
#       תכניות לימודים
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
#
#
# 14:15-12:30
# יום א'
# שנתי
# (א) שעור פרופ נעמי פלדמן
# הערה:
#   Comments:
#
#
# *******end of object********
#
#
# 15
# הפקולטה למדעי החברה :כלכלה
# Organizational Theory תיאוריה אירגונית   |   57900
# עבודה בכתב 2 ש"ש 4 נ"ז סמסטר ב' נלמד באנגלית
#       תכניות לימודים   סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
# 3613א' חבר (הר הצופים)
# 3613א' חבר (הר הצופים)
#
#
# 12:15-10:30
# 10:15-08:30
# יום א'
# יום ב'
# סמסטר ב
# סמסטר ב
# (א) שעור פרופ אירנה ולסקי
# הערה:
#   Comments:
#
#
# *******end of object********
#
#
# 16
# הפקולטה למדעי החברה :כלכלה
# Topics in Law and Economics נושאים במשפט וכלכלה   |   57401
# עבודה בכתב 2 ש"ש 4 נ"ז שנתי
#       תכניות לימודים   סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
#
#
# 16:15-14:30
# יום ג'
# שנתי
# (א) שעור פרופ יהונתן גבעתי
# הערה:
#   Comments:
#
#
# *******end of object********
#
#
# 17
#
#
# *******end of object********
#
#
# 18
# הפקולטה למדעי החברה :סטטיסטיקה
# GENERALIZED LINEAR MODELS מודלים לינארים מוכללים   |   52542
# עבודה בכתב 1.5 ש"ש 3 נ"ז סמסטר א' נלמד באנגלית
#       תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
#
#
# 14:15-11:30
# יום ד'
# סמסטר א
# (א) שעור פרופ שמואל אומן
# הערה:
# הקורס יינתן בשפה האנגלית.
# Comments:
# Course is taught in English.
#
# *******end of object********
#
#
# 19
# הפקולטה למדעי החברה :סטטיסטיקה
# BIOSTATISTICAL METHODS שיטות ביוסטטיסטיות   |   52755
# עבודה שוטפת 1.5 ש"ש 3 נ"ז סמסטר א' נלמד באנגלית
#       תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
#
#
# 19:45-17:00
# יום ב'
# סמסטר א
# (א) שעור פרופ דוד צוקר
# הערה:
# קורס בחירה לבוגר שנה ג'. קורס חובה לתלמידי מוסמך במגמה ביוסטטיסטיקה. הקורס יינתן בשפה האנגלית.
# Comments:
#
# *******end of object********
#
#
# 20
# הפקולטה למדעי החברה :סטטיסטיקה
# CATEGORICAL DATA ANALYSIS ניתוח נתונים קטגוריים   |   52700
# עבודה בכתב 1.5 ש"ש 3 נ"ז סמסטר ב'
#       תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
# 1711 חבר (הר הצופים)
#
# 16:15-13:30
# יום ד'
# סמסטר ב
# (א) שעור פרופ צבי גילולה
# הערה:
#   Comments:
#
#
# *******end of object********
#
#
# 21
# הפקולטה למדעי החברה :סטטיסטיקה
# PRINCIPLES OF EXPT DESIGN & SAMPLING METHODS עקרונות תכנון ניסויים ושיטות דגימה   |   52710
# משך הבחינה: 2.50 ש' בחינה בכתב 1.5 ש"ש 3 נ"ז סמסטר ב'
#       תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
# 2303 חבר (הר הצופים)
#
# 11:15-08:30
# יום ג'
# סמסטר ב
# (א) שעור פרופ בנימין יקיר
# הערה:
# קורס בחירה לבוגר שנה ג. קורס חובה למוסמך מגמת ביוסט'.
# Comments:
#
# *******end of object********
#
#
# 22
# הפקולטה למדעי החברה :סטטיסטיקה
# VARIANCE ESTIMATION IN SAMPLING FROM FINITE POPULATION אמידת שונות בדגימה מאוכולוסיות סופיות   |   52747
# משך הבחינה: 2.50 ש' בחינה בכתב 1.5 ש"ש 3 נ"ז סמסטר ב'
#       תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
# 3204 חבר (הר הצופים)
#
# 19:15-16:30
# יום א'
# סמסטר ב
# (א) שעור ד"ר אריה רייטר
# הערה:
#   Comments:
#
#
# *******end of object********
#
#
# 23
# הפקולטה למדעי החברה :סטטיסטיקה
# TIME SERIES ANALYSIS ניתוח סדרות עתיות   |   52640
# עבודה שוטפת 1.5 ש"ש 3 נ"ז סמסטר א' נלמד באנגלית
#       תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
#
#
# 16:15-13:30
# יום ג'
# סמסטר א
# (א) שות פרופ בנימין יקיר
# הערה:
# הקורס יינתן בשפה האנגלית
# Comments:
#
#
#
# יש לבחור עד 15 נ"ז מרשימה זו. כלכלה - קורס בחירה: תלמידי המסלול ישלימו את הנקודות החסרות בכלכלה ע"י קורסי בחירה במהלך התואר" 11 נ"ז מקורסי בחירה ו/או ליבה בחוג, 12 נ"ז מכלל הקורסים באוניברסיטה, בכפוף להנחיות המופיעות בשנתון המחלקה, ובאישור יועץ הב"א.
#
# *******end of object********
#
#
# 24
# הפקולטה למדעי החברה :כלכלה
# Economics as a Social Theory כלכלה כתיאוריה חברתית: ביקורת הכלכלה המדינית
# הקורס אינו מתקיים השנה   |   57642
# מבחן בית 1 ש"ש 2 נ"ז סמסטר א'
# דרישות קדם     תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
#
# *******end of object********
#
#
# 25
# הפקולטה למדעי החברה :כלכלה
# Programming in Stata תכנות ב-STATA
# הקורס אינו מתקיים השנה   |   57132
# משך הבחינה: 2.00 ש' בחינה בכתב 1 ש"ש 2 נ"ז סמסטר ב'
# דרישות קדם     תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
#
# *******end of object********
#
#
# 26
# הפקולטה למדעי החברה :כלכלה
# ADVANCED MATHEMATICS FOR ECONOMISTS מתמטיקה מתקדמת לכלכלנים   |   57556
# משך הבחינה: 2.50 ש' מבחן ממוחשב בבי 1.5 ש"ש 3 נ"ז סמסטר ב'
#       תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
# 2203 חבר (הר הצופים)
#
# 13:15-10:30
# יום ג'
# סמסטר ב
# (א) שעור פרופ אלחנן בן-פורת
# הערה:
# אופי הבחינה/המטלה הסופית עשוי להשתנות בהתאם להחלטות אוניברסיטאיות פקולטטיות לרגל המצב. דרישה מוקדמת: ציון עובר בקורסי שנה א' בכלכלה וכן בקורס 'אלגברה ליניארית לכלכלנים' (57509/52323).
# Comments:
# Prerequisite: Passing grade in all first-year economics courses and in Linear Algebra for Economics (57509/52323).
#
# *******end of object********
#
#
# 27
# הפקולטה למדעי החברה :כלכלה
# Social Identity and Economic Policy זהות חברתית ומדיניות כלכלית   |   57830
# עבודה בכתב 2 ש"ש 4 נ"ז סמסטר ב'
#       תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
# 4212 חבר - כלכלה
#
#
#
# 16:45-15:00
# 18:15-16:30
# יום ב'
# יום ד'
# סמסטר ב
# סמסטר ב
# (א) שעור פרופ משה שעיו
# הערה:
# הקורס פתוח לתלמידי ב"א, שממוצע ציוניהם בקורסים 'תורת המחירים א', 'תורת המחירים ב' ו'מבוא לאקונומטריקה הוא 90 לפחות.
# Comments:
#
# *******end of object********
#
#
# 28
# הפקולטה למדעי החברה :כלכלה
# DYNAMIC MODELS FOR ECONOMISTS מודלים דינמיים לכלכלנים   |   57973
# משך הבחינה: 2.00 ש' בחינה בכתב 1.5 ש"ש 3 נ"ז סמסטר א'
# דרישות קדם     תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
#
#
# 19:15-16:30
# יום א'
# סמסטר א
# (א) שעור ד"ר יונתן סטופ
# הערה:
# קורס מ"א פתוח גם לתלמידי ב"א שנה ג'. דרישה מוקדמת: ציון עובר בקורס אלגברה ליניארית לכלכלנים (57509/52323).
# Comments:
# Graduate course also available to third-year undergraduate students. Prerequisite: Passing grade in the courses Linear Algebra for Economics (57509/52323)
#
# *******end of object********
#
#
# 29
# ביה"ס למנהל העסקים :מנהל עסקים
# Fundamentals of Finance יסודות המימון   |   55803
# משך הבחינה: 3.00 ש' בחינה בכתב 1.5 ש"ש 3 נ"ז סמסטר א' או/ו ב'
# דרישות קדם קורסים חלופיים   תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
#
# באולם, וגם מועבר ...
# 17:15-14:30
# יום ד'
# סמסטר א
# (א) שעור פרופ אורלי שדה
# 2111 חבר (הר הצופים)
# באולם, וגם מועבר ...
# 15:45-13:00
# יום ב'
# סמסטר א
# (ב) שעור פרופ אורלי שדה
# 2113 חבר (הר הצופים)
#
# 15:45-13:00
# יום ב'
# סמסטר ב
# (ג) שעור פרופ אורלי שדה
# 2113 חבר (הר הצופים)
# בקמפוס
# 19:15-16:30
# יום ג'
# סמסטר ב
# (ד) שעור ד"ר מאיה שטאון
# 1708 חבר (הר הצופים)
#
# 16:45-16:00
# יום ב'
# סמסטר א
# (א) תרג
# 2102 חבר (הר הצופים)
#
# 18:15-17:30
# יום ד'
# סמסטר א
# (ב) תרג
# 2112 חבר (הר הצופים)
#
# 17:45-17:00
# יום ב'
# סמסטר ב
# (ג) תרג
# 2113 חבר (הר הצופים)
#
# 20:15-19:30
# יום ג'
# סמסטר ב
# (ד) תרג
# הערה:
# קדרישה מוקדמת: קורסים מס' 52116 ומס' 55701. בנוסף יש ללמוד לפני או במקביל את קורס מס' 55321. . ציון עובר בקורס הינו 60. לקבלת פטור מקורס מקביל בתואר שני, יש לעבור את הקורס בציון 70. התרגיל הינו רשות
# Comments:
# Prerequisite: Courses no. 52116, 55701. Also course no. 55321 concomitantly The passing grade is 60. In order to get exemption from the equivalent MBA course, the passing grade is 70.
#
# *******end of object********
