# %%
from time import sleep
from selenium import webdriver
from selenium.webdriver.support.ui import Select

#installation guide for selenium
#https://medium.com/@shanyitan/how-to-install-selenium-and-run-it-successfully-via-jupyter-lab-c3f50d22a0d4

# %%
#gathering information function
def gather(browser):
    main = browser.find_element_by_xpath("//*[@id='myBody']/table/tbody/tr/td/table/tbody/tr[5]/td/form/table/tbody/tr[3]/td")
    print(main.text)

# %%
browser = webdriver.Chrome()
browser.get("https://shnaton.huji.ac.il/")



select = Select(browser.find_element_by_id('faculty'))
select.select_by_value('07') #Pass value as string
sleep(1)

select = Select(browser.find_element_by_id('hugim'))
select.select_by_value('0824')
sleep(1)

select = Select(browser.find_element_by_id('maslul'))
select.select_by_value('7411')
sleep(1)

select = Select(browser.find_element_by_id('toar'))
select.select_by_value('1')
sleep(1)

select = Select(browser.find_element_by_id('shana'))
select.select_by_value('0')
sleep(1)

browser.find_element_by_css_selector("input[type='radio'][id='full']").click()
sleep(0.2)

browser.find_element_by_css_selector("input[type='button'][value=' חפש ']").click()

#collecting information
up = browser.find_element_by_xpath('//*[@id="myBody"]/table/tbody/tr/td/table/tbody/tr[5]/td/form/table/tbody/tr[3]/td/table[3]/tbody/tr/td[3]/a[2]')
try:
    while True:#information gathering function here
        browser.execute_script("window.scrollTo(0,document.body.scrollHeight)")
        sleep(1)
        gather(browser)
        up.click()
except:
    browser.close
# Out:
# שנתון 2020-2021 ( תשפ"א )
# תאריך עדכון 26-09-2020
#
# הפקולטה למדעי החברה
# דף 1 מתוך 2
#
# על מנת להציג פרטי הקורס יש ללחוץ על כותרת הקורס או לבחור בתפריט תצוגה משמאל את האופציה מפורט
#
# הצג תוצאות באופן
#
# מצומצם
#     מפורט
#  מצומצם מאוד
#         עבור מסלול
# חטיבה בסטטיסטיקה- חישוביות סטטיסטית היסקית (חס"ה)
# מתמטיקה סטטיסטיקה ומדע הנתונים במסלול דו חוגי
# סטטיסטיקה ומדע הנתונים בוגר דו-חוגי
# סטטיסטיקה מדע הנתונים בוגר חד חוגי
# סטטיסטיקה מדע הנתונים וכלכלה בוגר דו-חוגי
#
#
#
#     1   2  העמוד הבא
#
# סטטיסטיקה ומדע הנתונים (0824)
# סטטיסטיקה מדע הנתונים וכלכלה בוגר דו-חוגי (7411)
# בוגר
#
# תאור מסלול
#
#
# שנה א'
#
#
# קורסי חובה
#
#
# הפקולטה למדעי החברה :סטטיסטיקה
# Introduction to Programming מבוא לתכנות   |   52304
# משך הבחינה: 2.50 ש' בחינה בכתב 2 ש"ש 4 נ"ז סמסטר א'
#       תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
#
#
# 10:15-08:30
# יום ג'
# סמסטר א
# (א) שעור מר ינון קפלן
# 1701 חבר (הר הצופים)
#
# 14:15-12:30
# יום ג'
# סמסטר א
# (א) תרג מר יונתן וודבריג
# טבע 1 (הר הצופים)
#
# 14:15-12:30
# יום ג'
# סמסטר א
# (ב) תרג מר מתן בנדק
# טבע 2 (הר הצופים)
#
# 10:15-08:30
# יום ה'
# סמסטר א
# (ג) תרג מר מתן בנדק
# הערה:
# יש לבחור תרגיל א', ב' או ג'. תלמידי החוג אינטרנט וחברה - לא רשאים ללמוד קורס זה.
# Comments:
#
#
# הפקולטה למדעי החברה :סטטיסטיקה
# CALCULUS FOR STATISTICIANS A חשבון דיפרנציאלי ואינטגרלי לסטטיסטיקאים א'   |   52112
# משך הבחינה: 2.50 ש' בחינה בכתב 3 ש"ש 6 נ"ז סמסטר א'
#       תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
#
#
#
#
# 14:15-12:30
# 16:15-14:30
# יום א'
# יום ג'
# סמסטר א
# סמסטר א
# (א) שעור מר יונתן זוארי
#
#
#
#
# 14:45-13:00
# 12:15-10:30
# יום ב'
# יום ד'
# סמסטר א
# סמסטר א
# (ב) שעור פרופ יאן דולינסקי
# טבע 3 (הר הצופים)
#
# 12:15-10:30
# יום ה'
# סמסטר א
# (א) תרג מר בר וינשטיין
# טבע 3 (הר הצופים)
#
# 14:15-12:30
# יום ה'
# סמסטר א
# (ב) תרג מר בר וינשטיין
# טבע 2 (הר הצופים)
#
# 16:15-14:30
# יום ה'
# סמסטר א
# (ג) תרג מר הדר שרביט
# הערה:
# לבחירה שעור א' או ב' ותרגיל א', ב' או ג'.
# Comments:
#
#
# הפקולטה למדעי החברה :סטטיסטיקה
# CALCULUS FOR STATISTICIANS B חשבון דיפרנציאלי ואינטגרלי לסטטיסטיקאים ב   |   52113
# משך הבחינה: 2.50 ש' בחינה בכתב 3 ש"ש 6 נ"ז סמסטר ב'
#       תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
# 2109 חבר (הר הצופים)
# 2102 חבר (הר הצופים)
#
#
# 14:45-13:00
# 12:15-10:30
# יום ב'
# יום ד'
# סמסטר ב
# סמסטר ב
# (א) שעור פרופ יאן דולינסקי
# 2102 חבר (הר הצופים)
# 1701 חבר (הר הצופים)
#
#
# 14:15-12:30
# 16:15-14:30
# יום א'
# יום ד'
# סמסטר ב
# סמסטר ב
# (ב) שעור מר יונתן זוארי
# 1709 חבר (הר הצופים)
#
# 10:15-08:30
# יום ה'
# סמסטר ב
# (א) תרג מר הדר שרביט
# 1709 חבר (הר הצופים)
#
# 12:15-10:30
# יום ה'
# סמסטר ב
# (ב) תרג מר הדר שרביט
# 1709 חבר (הר הצופים)
#
# 14:15-12:30
# יום ה'
# סמסטר ב
# (ג) תרג מר בר וינשטיין
# הערה:
# דרישה מוקדמת: קורס 52112. לבחירה שעור א' או ב', ותרגיל א' ב' או ג'.
# Comments:
#
#
# הפקולטה למדעי החברה :סטטיסטיקה
# BASIC PROBABILITY יסודות ההסתברות   |   52220
# משך הבחינה: 3.00 ש' בחינה בכתב 3 ש"ש 6 נ"ז סמסטר ב'
#       תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
# טבע 2 (הר הצופים)
# טבע 2 (הר הצופים)
#
#
# 12:15-10:30
# 10:15-08:30
# יום א'
# יום ג'
# סמסטר ב
# סמסטר ב
# (א) שעור ד"ר אסף שריג
# 2110 חבר (הר הצופים)
#
# 16:15-14:30
# יום ג'
# סמסטר ב
# (א) תרג מר משה פירו
# 2304 חבר (הר הצופים)
#
# 18:15-16:30
# יום ג'
# סמסטר ב
# (ב) תרג מר יואל פרנקל
# 1711 חבר (הר הצופים)
#
# 16:15-14:30
# יום ג'
# סמסטר ב
# (ג) תרג גב שירה אלון
# הערה:
# יש לבחור תרגיל א', ב', או ג'.
# Comments:
#
#
# הפקולטה למדעי הרוח :אחר
# INFORMATION & LIBRARY RESOURCES הדרכה בשימוש בספרייה - קורס מתוקשב   |   74122
# השתתפות פעילה 0 ש"ש 0 נ"ז סמסטר א' או/ו ב'
#       תכניות לימודים אתר הקורס
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
#
#
#
#
# סמסטר א
# (א) הדר
#
#
#
#
# סמסטר ב
# (ב) הדר
# הערה:
# מדעי הרוח, מדעי החברה ומינהל עסקים
# Comments:
# Humanities, social sciences, and business administration
#
#
# כלכלה - קורסי המתמטיקה והסטטיסטיקה נלמדים ומשוקללים במסגרת המחלקה לסטטיסטיקה. יש להשלים את נקודות הזכות בגין קורסים אלה על ידי לימוד קורסי בחירה כמפורט בקטגורית קורסי הבחירה במסלול זה.
#
#
# הפקולטה למדעי החברה :כלכלה
# INTRODUCTION TO ECONOMICS I (MICRO) מבוא לכלכלה א (מיקרו)   |   57107
# משך הבחינה: 2.50 ש' בחינה בכתב 2 ש"ש 4 נ"ז סמסטר א'
#       תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
# טבע 1 (הר הצופים)
# טבע 1 (הר הצופים)
#
#
# 10:15-08:30
# 14:15-12:30
# יום ב'
# יום ד'
# סמסטר א
# סמסטר א
# (א) שות פרופ אסף זוסמן
# טבע 2 (הר הצופים)
# טבע 2 (הר הצופים)
#
#
# 12:15-10:30
# 12:15-10:30
# יום א'
# יום ה'
# סמסטר א
# סמסטר א
# (ב) שות ד"ר רפאל פרנק
# טבע 1 (הר הצופים)
# טבע 1 (הר הצופים)
#
#
# 10:15-08:30
# 10:15-08:30
# יום ג'
# יום ה'
# סמסטר א
# סמסטר א
# (ג) שות פרופ אסף זוסמן
# טבע 2 (הר הצופים)
# טבע 2 (הר הצופים)
#
#
# 16:15-14:30
# 12:15-10:30
# יום א'
# יום ג'
# סמסטר א
# סמסטר א
# (ד) שות ד"ר רפאל פרנק
#
#
#
#
# 20:15-18:30
# 20:15-18:30
# יום א'
# יום ד'
# סמסטר א
# סמסטר א
# (ה) שות ד"ר עופר רז-דרור
#
#
# 18:45-17:00
# יום ב'
# סמסטר א
# (א) מעב
#
#
# 14:15-12:30
# יום ג'
# סמסטר א
# (ב) מעב
#
#
# 10:15-08:30
# יום ד'
# סמסטר א
# (ג) מעב
# הערה:
# המעבדה (מרכז הלמידה) הינה רשות. בקורס מתקיים מרכז למידה בו המתרגלים עונים על שאלות בנושא חומר הלימוד של הקורס. אנו ממליצים לתכנן את מערכת השעות של הקורסים כך שתוכלו להגיע למרכז הלמידה (לאחד מתוך שלושת המועדים המוצעים). מרכז הלמידה יתקיים במועדים הבאים, החל משבוע הלימודים השני של הסמסטר: ימי ב' בין השעות 16:00-18:00 ימי ג' בין השעות 12:00-14:00 ימי ה' בין השעות 12:00-14:00 מקביל לקורסים 57001, 57002, 57003 שניתנו בשנים קודמות. קבוצה ה' תינתן בקמפוס גבעת רם. קורס מתכנית 'אבני פינה' בתחום החברתי.
# Comments:
# Elective learning center. This course offers a learning center (tutorial) where teaching assistants are available to answer questions about the material taught in this course. We recommend planning your class schedule so that you can attend the learning center (one of the three dates offered). The study center will be open on the following dates, starting the second week of the semester: Mondays 4:00pm-6:00pm; Tuesdays 12:00pm-2:00pm; Thursdays 12:00pm-2:00pm. Equivalent to courses 57001, 57002, 57003 offered in previous years. Group 4 is offered in the Givat Ram campus. Cornerstone course - Social.
#
# הפקולטה למדעי החברה :כלכלה
# INTRODUCTION TO ECONOMICS II (MACRO) מבוא לכלכלה ב (מקרו)   |   57108
# משך הבחינה: 2.50 ש' בחינה בכתב 2 ש"ש 4 נ"ז סמסטר ב'
# דרישות קדם     תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
# טבע 1 (הר הצופים)
# טבע 4 (הר הצופים)
#
#
# 18:15-16:30
# 20:15-18:30
# יום א'
# יום ד'
# סמסטר ב
# סמסטר ב
# (א) שות ד"ר אלון בנימיני
# טבע 3 (הר הצופים)
# טבע 3 (הר הצופים)
#
#
# 16:45-15:00
# 16:15-14:30
# יום ב'
# יום ד'
# סמסטר ב
# סמסטר ב
# (ב) שות ד"ר צחי רז
# טבע 2 (הר הצופים)
# טבע 2 (הר הצופים)
#
#
# 10:15-08:30
# 18:15-16:30
# יום ב'
# יום ד'
# סמסטר ב
# סמסטר ב
# (ג) שות ד"ר איתן רגב
# טבע 4 (הר הצופים)
#
# 18:45-17:00
# יום ב'
# סמסטר ב
# (א) מעב
# טבע 2 (הר הצופים)
#
# 12:15-10:30
# יום ג'
# סמסטר ב
# (ב) מעב
# 1708 חבר (הר הצופים)
#
# 14:15-12:30
# יום ה'
# סמסטר ב
# (ג) מעב
# 2110 חבר (הר הצופים)
#
# 16:45-15:00
# יום ב'
# סמסטר ב
# (ד) מעב
# הערה:
# אופי הבחינה/המטלה הסופית עשוי להשתנות בהתאם להחלטות אוניברסיטאיות פקולטטיות לרגל המצב. המעבדה (מרכז הלמידה) הינה רשות.בקורס מתקיים מרכז למידה, בו המתרגלים פותרים שאלות בנושא חומר הלימוד של הקורס. אנו ממליצים לתכנן את מערכת השעות של הקורסים כך שתוכלו להגיע למרכז הלמידה (לאחד מתוך ארבעת המועדים המוצעים). מקביל לקורסים 57004, 57005, 57006 שניתנו בשנים קודמות. דרישה מוקדמת: ציון בקורס 'מבוא לכלכלה א' (57107).
# Comments:
# This course offers an optional learning center (tutorial) where teaching assistants are available to answer questions about the material taught in this course. We recommend planning your class schedule so that you can attend the learning center (one of the four dates offered). Equivalent to courses 57004, 57005, 57006 offered in previous years. Prerequisite: Grade from the course Introduction to Economics 1 (57107).
#
# הפקולטה למדעי הרוח :אחר
# INFORMATION & LIBRARY RESOURCES הדרכה בשימוש בספרייה - קורס מתוקשב   |   74122
# השתתפות פעילה 0 ש"ש 0 נ"ז סמסטר א' או/ו ב'
#       תכניות לימודים אתר הקורס
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
#
#
#
#
# סמסטר א
# (א) הדר
#
#
#
#
# סמסטר ב
# (ב) הדר
# הערה:
# מדעי הרוח, מדעי החברה ומינהל עסקים
# Comments:
# Humanities, social sciences, and business administration
#
#
# שנה ב'
#
# הפקולטה למדעי החברה :סטטיסטיקה
# Linear Algebra for Statistics אלגברה לינארית לסטטיסטיקאים   |   52322
# משך הבחינה: 2.50 ש' בחינה בכתב 2 ש"ש 4 נ"ז סמסטר א'
#       תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
#
#
#
#
# 16:15-14:30
# 11:15-10:30
# יום א'
# יום ב'
# סמסטר א
# סמסטר א
# (א) שעור פרופ יאן דולינסקי
#
#
# 12:15-11:30
# יום ב'
# סמסטר א
# (א) תרג מר הדר שרביט
# הערה:
#   Comments:
#
# הפקולטה למדעי החברה :סטטיסטיקה
# PRINCIPLES AND APPLICATIONS IN STAT ANALYSIS עקרונות ויישומים בניתוח סטטיסטי   |   52221
# משך הבחינה: 2.50 ש' בחינה בכתב 2.5 ש"ש 5 נ"ז סמסטר א'
# דרישות קדם     תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
#
#
# 13:15-10:30
# יום ג'
# סמסטר א
# (א) שעור פרופ מיכה מנדל
#
#
# 10:15-08:30
# יום ה'
# סמסטר א
# (א) תרג מר יואל פרנקל
#
#
# 12:15-10:30
# יום ה'
# סמסטר א
# (ב) תרג מר יואל פרנקל
# הערה:
# דרישה מוקדמת: ציון עובר בקורס 52220. יש לבחור קבוצת תרגיל אחת.
# Comments:
# Prerequisite: Passing grade in course 52220. You must enroll in one Tutorial only.
#
# הפקולטה למדעי החברה :סטטיסטיקה
# Data structures and algorithms מבני נתונים ואלגוריתמים   |   52411
# משך הבחינה: 2.50 ש' בחינה בכתב 2 ש"ש 4 נ"ז סמסטר א'
# דרישות קדם     תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
#
#
# 14:45-13:00
# יום ב'
# סמסטר א
# (א) שעור פרופ גל אלידן
#
#
# 16:15-14:30
# יום ג'
# סמסטר א
# (א) תרג מר יובל להב
# הערה:
# תנאי קדם - ציון עובר בקורס 52304 'מבוא לתכנות' או קורס חליפי בכפוף לאישור בכתב מהמרצה.
# Comments:
#
#
# הפקולטה למדעי החברה :סטטיסטיקה
# REGRESSION AND STATISTICAL MODELS רגרסיה ומודלים סטטיסטיים   |   52571
# משך הבחינה: 3.00 ש' בחינה בכתב 3 ש"ש 6 נ"ז סמסטר ב'
#       תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
# טבע 4 (הר הצופים)
# 2109 חבר (הר הצופים)
#
#
# 14:15-12:30
# 12:15-10:30
# יום א'
# יום ב'
# סמסטר ב
# סמסטר ב
# (א) שעור ד"ר אסף ויינשטיין
# 1708 חבר (הר הצופים)
#
# 14:15-12:30
# יום ד'
# סמסטר ב
# (א) תרג גב שיר משה
# 2204 חבר (הר הצופים)
#
# 14:15-12:30
# יום ד'
# סמסטר ב
# (ב) תרג מר בר וינשטיין
# הערה:
#   Comments:
#
# הפקולטה למדעי החברה :סטטיסטיקה
# Probability for Statistics students הסתברות לסטטיסטיקאים   |   52324
# משך הבחינה: 2.50 ש' בחינה בכתב 2 ש"ש 4 נ"ז סמסטר ב'
#       תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
# טבע 3 (הר הצופים)
#
# 19:45-17:00
# יום ב'
# סמסטר ב
# (א) שעור פרופ בנימין יקיר
# טבע 4 (הר הצופים)
#
# 12:15-11:30
# יום ד'
# סמסטר ב
# (א) תרג מר נדב הר-טוב
# הערה:
#   Comments:
#
# הפקולטה למדעי החברה :סטטיסטיקה
# Data Analysis with R ניתוח נתונים עם R   |   52414
# מבחן בית 1 ש"ש 2 נ"ז סמסטר ב'
#       תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
# טבע 2 (הר הצופים)
#
# 16:15-14:30
# יום ד'
# סמסטר ב
# (א) שעור ד"ר אור צוק
# הערה:
#   Comments:
#
#
# כלכלה
#
#
# הפקולטה למדעי החברה :כלכלה
# MACRO ECONOMICS I מקרו-כלכלה א   |   57305
# משך הבחינה: 2.00 ש' בחינה בכתב 2 ש"ש 4 נ"ז סמסטר א'
#       תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
#
#
#
#
# 16:15-14:30
# 16:15-14:30
# יום א'
# יום ג'
# סמסטר א
# סמסטר א
# (א) שות פרופ אורי חפץ
# ד"ר אדוארד אופנבכר
#
#
#
#
# 16:45-15:00
# 16:15-14:30
# יום ב'
# יום ד'
# סמסטר א
# סמסטר א
# (ב) שות פרופ אורי חפץ
# ד"ר אדוארד אופנבכר
#
#
#
#
# 12:15-10:30
# 18:15-16:30
# יום א'
# יום ה'
# סמסטר א
# סמסטר א
# (ג) שות פרופ אורי חפץ
# ד"ר אדוארד אופנבכר
#
#
# 12:15-10:30
# יום ג'
# סמסטר א
# (א) מעב
#
#
# 14:15-12:30
# יום ד'
# סמסטר א
# (ב) מעב
# הערה:
# המעבדה (מרכז הלמידה) הינה רשות. בקורס מתקיים מרכז למידה, בו המתרגלים עונים על שאלות בנושא חומר הלימוד של הקורס. אנו ממליצים לתכנן את מערכת השעות של הקורסים כך שתוכלו להגיע למרכז הלמידה (לאחד מתוך שני המועדים המוצעים). מרכז הלמידה יתקיים במועדים הבאים, החל משבוע הלימודים השני של הסמסטר: ימי ג' בין השעות 10:00-12:00 ימי ד' בין השעות 12:00-14:00 דרישה מוקדמת: עמידה בתנאי המעבר/מעבר על תנאי לשנה ב'.
# Comments:
# Elective learning center. This course offers a learning center (tutorial) where teaching assistants are available to answer questions about the material taught in this course. We recommend planning your class schedule so that you can attend the learning center (one of the two dates offered). The learning center will be open on the following dates, starting the second week of the semester: Tuesdays 10:00am-12:00pm; Wednesdays 12:00pm-2:00pm. Prerequisite: satisfy the terms for progressing / conditional admission to the second year.
#
# הפקולטה למדעי החברה :כלכלה
# PRICE-THEORY I תורת המחירים א   |   57307
# משך הבחינה: 2.50 ש' בחינה בכתב 2 ש"ש 4 נ"ז סמסטר א'
#       תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
#
#
#
#
# 18:45-17:00
# 14:15-12:30
# יום ב'
# יום ה'
# סמסטר א
# סמסטר א
# (א) שות פרופ משה שעיו
# ד"ר אלון איזנברג
#
#
#
#
# 10:15-08:30
# 10:15-08:30
# יום ב'
# יום ד'
# סמסטר א
# סמסטר א
# (ב) שות פרופ משה שעיו
# ד"ר אלון איזנברג
#
#
#
#
# 10:15-08:30
# 10:15-08:30
# יום ג'
# יום ה'
# סמסטר א
# סמסטר א
# (ג) שות פרופ משה שעיו
# ד"ר אלון איזנברג
#
#
# 20:45-19:00
# יום ב'
# סמסטר א
# (א) מעב
#
#
# 14:15-12:30
# יום ג'
# סמסטר א
# (ב) מעב
# הערה:
# המעבדה (מרכז הלמידה) הינה רשות. בקורס מתקיים מרכז למידה, בו המתרגלים עונים על שאלות בנושא חומר הלימוד של הקורס. אנו ממליצים לתכנן את מערכת השעות של הקורסים כך שתוכלו להגיע למרכז הלמידה (לאחד מתוך שני המועדים המוצעים). מרכז הלמידה יתקיים החל משבוע השני ללימודים. מקביל לקורסים 57301, 57302 שניתנו בשנים קודמות. דרישה מוקדמת: עמידה בתנאי המעבר/מעבר 'על תנאי' לשנה ב'.
# Comments:
# Elective learning center. This course offers a learning center (tutorial) where teaching assistants are available to answer questions about the material taught in this course. We recommend planning your class schedule so that you can attend the learning center (one of the two dates offered). The study center will be open starting the second week of the semester: Equivalent to courses 57301, 57302 offered in previous years. Prerequisite: satisfy the terms for progressing / conditional admission to the second year.
#
# הפקולטה למדעי החברה :כלכלה
# INTRODUCTION TO ECONOMETRICS מבוא לאקונומטריקה   |   57322
# מבחן בית 2 ש"ש 4 נ"ז סמסטר א'
#       תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
#
#
#
#
# 20:15-18:30
# 16:15-14:30
# יום א'
# יום ה'
# סמסטר א
# סמסטר א
# (א) שעור פרופ אריק גולד
# פרופ נעמי פלדמן
#
#
#
#
# 14:45-13:00
# 18:15-16:30
# יום ב'
# יום ד'
# סמסטר א
# סמסטר א
# (ב) שעור פרופ אריק גולד
# פרופ נעמי פלדמן
#
#
#
#
# 12:15-10:30
# 20:15-18:30
# יום ב'
# יום ד'
# סמסטר א
# סמסטר א
# (ג) שעור פרופ אריק גולד
# פרופ נעמי פלדמן
#
#
# 18:15-16:30
# יום א'
# סמסטר א
# (א) תרג
#
#
# 20:15-18:30
# יום א'
# סמסטר א
# (ב) תרג
#
#
# 18:15-16:30
# יום ג'
# סמסטר א
# (ג) תרג
#
#
# 18:15-16:30
# יום ה'
# סמסטר א
# (ד) תרג
# הערה:
# אופי הבחינה/המטלה הסופית עשוי להשתנות בהתאם להחלטות אוניברסיטאיות פקולטטיות לרגל המצב. פרופ' אריק גולד ופרופ' נעמי פלדמן ילמדו במשותף את כל קבוצות השיעור. דרישה מוקדמת: עמידה בתנאי המעבר/מעבר על תנאי לשנה ב'.
# Comments:
# Prof. Eric Gould and Prof. Naomi Feldman will teach all the groups jointly. Prerequisite: satisfy the terms for progressing / conditional admission to the second year
#
# הפקולטה למדעי החברה :כלכלה
# PRICE THEORY II תורת המחירים ב   |   57308
# משך הבחינה: 2.50 ש' בחינה בכתב 2 ש"ש 4 נ"ז סמסטר ב'
#       תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
# 1701 חבר (הר הצופים)
# 1701 חבר (הר הצופים)
#
#
# 20:45-19:00
# 16:15-14:30
# יום ב'
# יום ה'
# סמסטר ב
# סמסטר ב
# (א) שות פרופ אלכסנדר הרשקוב
# ד"ר ג'פרי מנש
# 1701 חבר (הר הצופים)
# 1701 חבר (הר הצופים)
#
#
# 12:15-10:30
# 10:15-08:30
# יום ג'
# יום ה'
# סמסטר ב
# סמסטר ב
# (ב) שות פרופ אלכסנדר הרשקוב
# ד"ר ג'פרי מנש
# 1701 חבר (הר הצופים)
# 1701 חבר (הר הצופים)
#
#
# 10:15-08:30
# 18:15-16:30
# יום ב'
# יום ד'
# סמסטר ב
# סמסטר ב
# (ג) שות פרופ אלכסנדר הרשקוב
# ד"ר ג'פרי מנש
# 3301 חבר (הר הצופים)
#
# 14:15-12:30
# יום ג'
# סמסטר ב
# (א) מעב
# 3304 חבר (הר הצופים)
#
# 16:15-14:30
# יום ד'
# סמסטר ב
# (ב) מעב
# הערה:
# אופי הבחינה/המטלה הסופית עשוי להשתנות בהתאם להחלטות אוניברסיטאיות פקולטטיות לרגל המצב. המעבדה (מרכז הלמידה) הינה רשות. בקורס מתקיים מרכז למידה, בו המתרגלים עונים על שאלות בנושא חומר הלימוד של הקורס. מקביל לקורסים 57309, 57310 שניתנו בשנים קודמות. דרישה מוקדמת: ציון בקורס 'תורת המחירים א' (57307).
# Comments:
# Elective learning center. This course offers a learning center (tutorial) where teaching assistants are available to answer questions about the material taught in this course. Equivalent to courses 57309, 57310 offered in previous years. Prerequisite: Grade from the course Price Theory 1 (57307).
#
#
# שנה ג'
#
# הפקולטה למדעי החברה :סטטיסטיקה
# STATISTICS LAB מעבדה בסטטיסטיקה   |   52568
# עבודה בכתב 1.5 ש"ש 3 נ"ז סמסטר א'
#       תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
#
#
# 14:15-11:30
# יום א'
# סמסטר א
# (א) שעור ד"ר אור צוק
# הערה:
#   Comments:
#
# הפקולטה למדעי החברה :סטטיסטיקה
# Statistical Inference and Its Applications הסקה סטטיסטית ושימושיה   |   52325
# משך הבחינה: 2.50 ש' בחינה בכתב 3 ש"ש 6 נ"ז סמסטר א'
#       תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
#
#
#
#
# 16:15-14:30
# 16:15-14:30
# יום א'
# יום ד'
# סמסטר א
# סמסטר א
# (א) שעור פרופ פבל צ'יגנסקי
#
#
# 20:15-18:30
# יום ד'
# סמסטר א
# (א) תרג גב רחל בוצ'וק
# הערה:
#   Comments:
#
# הפקולטה למדעי החברה :סטטיסטיקה
# Statistical learning and data analysis למידה סטטיסטית וניתוח נתונים   |   52525
# מבחן בית 2 ש"ש 4 נ"ז סמסטר ב'
#       תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
# 2102 חבר (הר הצופים)
# טבע 4 (הר הצופים)
#
#
# 18:15-16:30
# 17:15-16:30
# יום ג'
# יום ד'
# סמסטר ב
# סמסטר ב
# (א) שעור ד"ר יובל בנימיני
# טבע 4 (הר הצופים)
#
# 18:15-17:30
# יום ד'
# סמסטר ב
# (א) תרג גב ספיר חן-ציון
# הערה:
# תלמידים שלמדו את הקורס 52311 'עיבוד נתונים בסטטיסטיקה מודרנית' אינם רשאים ללמוד קורס זה.
# Comments:
# Not available to students who completed course no. 52311 Data Processing in Modern Statistics.
#
# הפקולטה למדעי החברה :סטטיסטיקה
# Big Data Mining. כריית מידע מנתונים גדולים   |   52002
# משך הבחינה: 2.50 ש' בחינה בכתב 1.5 ש"ש 3 נ"ז סמסטר ב'
# דרישות קדם     תכניות לימודים
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
# טבע 4 (הר הצופים)
#
# 14:15-11:30
# יום ג'
# סמסטר ב
# (א) שעור ד"ר אור צוק
# הערה:
# תנאי קדם: 52304 מבוא לתכנות ו- 52411 מבנה נתונים ואלגוריתמים. תלמיד שלמד 47717 "ניתוח מאגרי מידע", לא רשאי ללמוד קורס זה. תלמידי החוג אינטרנט וחברה לא רשאים ללמוד קורס זה
# Comments:
#
#
#
# קורסי חובת בחירה שנה ג'
#
#
#
# . קורסי ליבה - מיועדים לתלמידי שנה ג' במחלקה לכלכלה. יש לבחור אחד מבין הקורסים הבאים:
#
#
# הפקולטה למדעי החברה :כלכלה
# Risk, uncertainty and information סיכון, אי ודאות ואינפורמציה   |   57499
# משך הבחינה: 2.50 ש' בחינה בכתב 2 ש"ש 4 נ"ז סמסטר א' נלמד באנגלית
#       תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
#
#
#
#
# 16:15-14:30
# 10:15-08:30
# יום א'
# יום ג'
# סמסטר א
# סמסטר א
# (א) שעור פרופ אירנה ולסקי
# הערה:
#   Comments:
#
# הפקולטה למדעי החברה :כלכלה
# Urban Economics כלכלה עירונית
# הקורס אינו מתקיים השנה   |   57516
# משך הבחינה: 2.00 ש' בחינה בכתב 2 ש"ש 4 נ"ז סמסטר א'
# דרישות קדם     תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
#
# הפקולטה למדעי החברה :כלכלה
# The Financial System, the Global Financial Crisis and המערכת הפיננסית, המשבר הפיננסי הגלובלי והניתוח במאקרו-כלכלה   |   57253
# מבחן בית 2 ש"ש 4 נ"ז סמסטר א'
#       תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
#
#
#
#
# 12:15-10:30
# 12:15-10:30
# יום ב'
# יום ד'
# סמסטר א
# סמסטר א
# (א) שעור ד"ר אדוארד אופנבכר
# הערה:
#   Comments:
#
# הפקולטה למדעי החברה :כלכלה
# Topics in Macroeconomics of Uncertainty and Financial Markets נושאים במקרו כלכלה של אי-ודאות ושווקים פיננסים   |   57311
# משך הבחינה: 2.50 ש' בחינה בכתב 2 ש"ש 4 נ"ז סמסטר ב'
#       תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
# 2303 חבר (הר הצופים)
# 2303 חבר (הר הצופים)
#
#
# 18:15-16:30
# 18:15-16:30
# יום ג'
# יום ה'
# סמסטר ב
# סמסטר ב
# (א) שעור ד"ר ערן הופמן
# הערה:
# אופי הבחינה/המטלה הסופית עשוי להשתנות בהתאם להחלטות אוניברסיטאיות פקולטטיות לרגל המצב.
# Comments:
#
#
# הפקולטה למדעי החברה :כלכלה
# POLITICAL ECONOMY כלכלה פוליטית   |   57807
# משך הבחינה: 2.50 ש' בחינה בכתב 2 ש"ש 4 נ"ז סמסטר א'
# דרישות קדם     תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
#
#
#
#
# 12:15-10:30
# 12:15-10:30
# יום ב'
# יום ה'
# סמסטר א
# סמסטר א
# (א) שות פרופ אסטבן קלור
# הערה:
# דרישה מוקדמת: ציון עובר בקורסים 'תורת המחירים א' וב' (57307, 57308).
# Comments:
#
#
# הפקולטה למדעי החברה :תכנית משולבת:פילוסופיה,כלכלה,מדע המדינה
# Economic History הסטוריה כלכלית   |   54121
# עבודה בכתב 2 ש"ש 4 נ"ז סמסטר ב'
#       תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
# 1708 חבר (הר הצופים)
# 1708 חבר (הר הצופים)
#
#
# 14:45-13:00
# 12:15-10:30
# יום ב'
# יום ה'
# סמסטר ב
# סמסטר ב
# (א) שות ד"ר צחי רז
# הערה:
# תנאי קדם לתלמידי תכנית פכ"מ והמחלקה לכלכלה: ציון כלשהו במחירים א' ובמחירים ב' במקרים חריגים יאושר לימוד במקביל של הקורסים מחירים א' וב' שות א לחוג 321,326.
# Comments:
#
#
# הפקולטה למדעי החברה :כלכלה
# ECONOMIC GROWTH צמיחה כלכלית
# הקורס אינו מתקיים השנה   |   57617
# משך הבחינה: 2.00 ש' בחינה בכתב 2 ש"ש 4 נ"ז סמסטר א'
# דרישות קדם     תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
#
#
#
# הצג תוצאות באופן
#
# מצומצם
#     מפורט
#     מצומצם מאוד
#         עבור מסלול
# חטיבה בסטטיסטיקה- חישוביות סטטיסטית היסקית (חס"ה)
# מתמטיקה סטטיסטיקה ומדע הנתונים במסלול דו חוגי
# סטטיסטיקה ומדע הנתונים בוגר דו-חוגי
# סטטיסטיקה מדע הנתונים בוגר חד חוגי
# סטטיסטיקה מדע הנתונים וכלכלה בוגר דו-חוגי
#
#
# :עבור לדף 1   2  העמוד הבא
# שנתון 2020-2021 ( תשפ"א )
# תאריך עדכון 26-09-2020
#
# הפקולטה למדעי החברה
# דף 2 מתוך 2
#
# על מנת להציג פרטי הקורס יש ללחוץ על כותרת הקורס או לבחור בתפריט תצוגה משמאל את האופציה מפורט
#
# הצג תוצאות באופן
#
# מצומצם
#     מפורט
#  מצומצם מאוד
#         עבור מסלול
# חטיבה בסטטיסטיקה- חישוביות סטטיסטית היסקית (חס"ה)
# מתמטיקה סטטיסטיקה ומדע הנתונים במסלול דו חוגי
# סטטיסטיקה ומדע הנתונים בוגר דו-חוגי
# סטטיסטיקה מדע הנתונים בוגר חד חוגי
# סטטיסטיקה מדע הנתונים וכלכלה בוגר דו-חוגי
#
#
#
#     העמוד הקודם  1   2
#
# סטטיסטיקה ומדע הנתונים (0824)
# סטטיסטיקה מדע הנתונים וכלכלה בוגר דו-חוגי (7411)
# בוגר
#
# תאור מסלול
#
#
# שנה ג'
# קורסי חובת בחירה
# . קורסי ליבה - מיועדים לתלמידי שנה ג' במחלקה לכלכלה. יש לבחור אחד מבין הקורסים הבאים:
#
#
# הפקולטה למדעי החברה :כלכלה
# Exchange Rates and International Macroeconomics שערי חליפין ומאקרו-כלכלה בין-לאומית   |   57676
# עבודה בכתב 2 ש"ש 4 נ"ז סמסטר ב'
#       תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
# 1706 חבר (הר הצופים)
# 1706 חבר (הר הצופים)
#
#
# 18:45-17:00
# 10:15-08:30
# יום ב'
# יום ד'
# סמסטר ב
# סמסטר ב
# (א) שעור ד"ר רפאל פרנק
# הערה:
# אופי הבחינה/המטלה הסופית עשוי להשתנות בהתאם להחלטות אוניברסיטאיות פקולטטיות לרגל המצב. דרישה מוקדמת: ציון עובר בקורסים מחירים א', מאקרו א' ומבוא לאקונומטריקה.
# Comments:
#
#
# הפקולטה למדעי החברה :כלכלה
# Labor Econmics כלכלת עבודה
# הקורס אינו מתקיים השנה   |   57256
# משך הבחינה: 2.50 ש' בחינה בכתב 2 ש"ש 4 נ"ז סמסטר א'
#       תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
#
# הפקולטה למדעי החברה :כלכלה
# International Trade and Development מסחר בינלאומי ופיתוח   |   57257
# עבודה בכתב 2 ש"ש 4 נ"ז סמסטר ב' נלמד באנגלית
#       תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
# 1711 חבר (הר הצופים)
#
# 12:15-08:30
# יום ב'
# סמסטר ב
# (א) שעור ד"ר איב סירה
# הערה:
#   Comments:
#
# הפקולטה למדעי החברה :כלכלה
# Regulation, Antitrust and the Theory of the Firm פיקוח, הגבלים עסקיים ותורת הפירמה
# הקורס אינו מתקיים השנה   |   57670
# משך הבחינה: 2.50 ש' בחינה בכתב 2 ש"ש 4 נ"ז סמסטר ב'
# דרישות קדם     תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
#
#
# . קורסי חקר - מיועדים לתלמידי שנה ג' במחלקה לכלכלה. יש לבחור אחד מבין הקורסים הבאים, ולכתוב במסגרתו עבודת חקר
#
#
# הפקולטה למדעי החברה :כלכלה
# Topics in Market Design נושאים בעיצוב שווקים   |   57255
# עבודה בכתב 2 ש"ש 4 נ"ז סמסטר א'
#       תכניות לימודים
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
#
#
#
#
# 10:15-08:30
# 10:15-08:30
# יום ג'
# יום ה'
# סמסטר א
# סמסטר א
# (א) שעור ד"ר אסף רום
# הערה:
# דרישות קדם: מחירים ב'
# Comments:
#
#
# הפקולטה למדעי החברה :כלכלה
# Topics in Applied Microeconomics נושאים במיקרו-כלכלה יישומית   |   57643
# עבודה בכתב 2 ש"ש 4 נ"ז שנתי
# דרישות קדם     תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
#
#
# 14:15-12:30
# יום ה'
# שנתי
# (א) שעור פרופ אסף זוסמן
# הערה:
# דרישה מוקדמת: ציון עובר ב'מבוא לאקונומטריקה' (57322).
# Comments:
#
#
# הפקולטה למדעי החברה :כלכלה
# Research Course in Applied Economics כלכלה יישומית   |   57639
# עבודה בכתב 2 ש"ש 4 נ"ז סמסטר ב' נלמד באנגלית
# דרישות קדם     תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
# 3202 חבר (הר הצופים)
# 3202 חבר (הר הצופים)
#
#
# 18:45-17:00
# 18:15-16:30
# יום ב'
# יום ד'
# סמסטר ב
# סמסטר ב
# (א) שעור ד"ר נעמי האוזמן
# הערה:
# ההרצאות יינתנו באנגלית; את העבודות ניתן לכתוב באנגלית או בעברית. דרישה מוקדמת: ציון עובר בקורסים 'תורת המחירים א' וב' (57307, 57308) ו'מבוא לאקונומטריקה' (57322).
# Comments:
#
#
# הפקולטה למדעי החברה :כלכלה
# TOPICS IN POLITICAL ECONOMY נושאים בכלכלה פוליטית   |   57736
# עבודה בכתב 2 ש"ש 4 נ"ז שנתי
#       תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
#
#
# 10:15-08:30
# יום ה'
# שנתי
# (א) שעור פרופ אסטבן קלור
# הערה:
# דרישה מוקדמת: מבוא לאקונומטריקה (57322).
# Comments:
#
#
# הפקולטה למדעי החברה :כלכלה
# Topics in Empirical Microeconomics נושאים במיקרו כלכלה אמפירית   |   57152
# עבודה בכתב 2 ש"ש 4 נ"ז סמסטר א'
# דרישות קדם     תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
#
#
#
#
# 16:45-15:00
# 16:15-14:30
# יום ב'
# יום ד'
# סמסטר א
# סמסטר א
# (א) שעור פרופ שאול לאך
# הערה:
# דרישה מוקדמת: ציון עובר במבוא לאקונומטריקה (57322).
# Comments:
# Prerequisite: Passing grade in Introduction to Econometrics (57322).
#
# הפקולטה למדעי החברה :כלכלה
# The Economics of Migration כלכלת הגירה   |   57811
# עבודה בכתב 2 ש"ש 4 נ"ז סמסטר א' נלמד באנגלית
#       תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
#
#
#
#
# 16:15-14:30
# 16:15-14:30
# יום א'
# יום ה'
# סמסטר א
# סמסטר א
# (א) שעור ד"ר מיכאל עמיאור
# הערה:
# תנאי קדם: ציון עובר בקורס מבוא לאקונומטריקה
# Comments:
#
#
# הפקולטה למדעי החברה :כלכלה
# Topics in Game Theory נושאים בתורת המשחקים   |   57200
# עבודה בכתב 2 ש"ש 4 נ"ז שנתי נלמד באנגלית
#       תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
#
#
# 18:15-16:30
# יום א'
# שנתי
# (א) שעור פרופ אירנה ולסקי
# הערה:
#   Comments:
#
# הפקולטה למדעי החברה :כלכלה
# Selected Topics in Behavioral Economics סוגיות נבחרות בכלכלה התנהגותית   |   57128
# עבודה בכתב 2 ש"ש 4 נ"ז סמסטר א'
#       תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
#
#
#
#
# 18:45-17:00
# 18:15-16:30
# יום ב'
# יום ד'
# סמסטר א
# סמסטר א
# (א) שעור פרופ אייל וינטר
# הערה:
#   Comments:
#
# הפקולטה למדעי החברה :כלכלה
# Topics in Empirical Tax Research נושאים בחקר המיסוי אמפירי   |   57469
# עבודה בכתב 2 ש"ש 4 נ"ז שנתי
#       תכניות לימודים
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
#
#
# 14:15-12:30
# יום א'
# שנתי
# (א) שעור פרופ נעמי פלדמן
# הערה:
#   Comments:
#
# הפקולטה למדעי החברה :כלכלה
# Organizational Theory תיאוריה אירגונית   |   57900
# עבודה בכתב 2 ש"ש 4 נ"ז סמסטר ב' נלמד באנגלית
#       תכניות לימודים   סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
# 3613א' חבר (הר הצופים)
# 3613א' חבר (הר הצופים)
#
#
# 12:15-10:30
# 10:15-08:30
# יום א'
# יום ב'
# סמסטר ב
# סמסטר ב
# (א) שעור פרופ אירנה ולסקי
# הערה:
#   Comments:
#
# הפקולטה למדעי החברה :כלכלה
# Topics in Law and Economics נושאים במשפט וכלכלה   |   57401
# עבודה בכתב 2 ש"ש 4 נ"ז שנתי
#       תכניות לימודים   סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
#
#
# 16:15-14:30
# יום ג'
# שנתי
# (א) שעור פרופ יהונתן גבעתי
# הערה:
#   Comments:
#
#
# קורסי בחירה שנה ג'
#
#
#
# . סטטיסטיקה: יש לבחור 2 קורסי בחירה (6 נ"ז). לתשומת לבכם - תלמידים לתואר בוגר בפקולטה למדעי החברה, מחויבים במסגרת לימודי הבחירה ללמוד קורס בשפה האנגלית בהיקף 2 נ"ז לפחות (באחד מהחוגים).
#
#
# הפקולטה למדעי החברה :סטטיסטיקה
# GENERALIZED LINEAR MODELS מודלים לינארים מוכללים   |   52542
# עבודה בכתב 1.5 ש"ש 3 נ"ז סמסטר א' נלמד באנגלית
#       תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
#
#
# 14:15-11:30
# יום ד'
# סמסטר א
# (א) שעור פרופ שמואל אומן
# הערה:
# הקורס יינתן בשפה האנגלית.
# Comments:
# Course is taught in English.
#
# הפקולטה למדעי החברה :סטטיסטיקה
# BIOSTATISTICAL METHODS שיטות ביוסטטיסטיות   |   52755
# עבודה שוטפת 1.5 ש"ש 3 נ"ז סמסטר א' נלמד באנגלית
#       תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
#
#
# 19:45-17:00
# יום ב'
# סמסטר א
# (א) שעור פרופ דוד צוקר
# הערה:
# קורס בחירה לבוגר שנה ג'. קורס חובה לתלמידי מוסמך במגמה ביוסטטיסטיקה. הקורס יינתן בשפה האנגלית.
# Comments:
#
#
# הפקולטה למדעי החברה :סטטיסטיקה
# CATEGORICAL DATA ANALYSIS ניתוח נתונים קטגוריים   |   52700
# עבודה בכתב 1.5 ש"ש 3 נ"ז סמסטר ב'
#       תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
# 1711 חבר (הר הצופים)
#
# 16:15-13:30
# יום ד'
# סמסטר ב
# (א) שעור פרופ צבי גילולה
# הערה:
#   Comments:
#
# הפקולטה למדעי החברה :סטטיסטיקה
# PRINCIPLES OF EXPT DESIGN & SAMPLING METHODS עקרונות תכנון ניסויים ושיטות דגימה   |   52710
# משך הבחינה: 2.50 ש' בחינה בכתב 1.5 ש"ש 3 נ"ז סמסטר ב'
#       תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
# 2303 חבר (הר הצופים)
#
# 11:15-08:30
# יום ג'
# סמסטר ב
# (א) שעור פרופ בנימין יקיר
# הערה:
# קורס בחירה לבוגר שנה ג. קורס חובה למוסמך מגמת ביוסט'.
# Comments:
#
#
# הפקולטה למדעי החברה :סטטיסטיקה
# VARIANCE ESTIMATION IN SAMPLING FROM FINITE POPULATION אמידת שונות בדגימה מאוכולוסיות סופיות   |   52747
# משך הבחינה: 2.50 ש' בחינה בכתב 1.5 ש"ש 3 נ"ז סמסטר ב'
#       תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
# 3204 חבר (הר הצופים)
#
# 19:15-16:30
# יום א'
# סמסטר ב
# (א) שעור ד"ר אריה רייטר
# הערה:
#   Comments:
#
# הפקולטה למדעי החברה :סטטיסטיקה
# TIME SERIES ANALYSIS ניתוח סדרות עתיות   |   52640
# עבודה שוטפת 1.5 ש"ש 3 נ"ז סמסטר א' נלמד באנגלית
#       תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
#
#
# 16:15-13:30
# יום ג'
# סמסטר א
# (א) שות פרופ בנימין יקיר
# הערה:
# הקורס יינתן בשפה האנגלית
# Comments:
#
#
#
# יש לבחור עד 15 נ"ז מרשימה זו. כלכלה - קורס בחירה: תלמידי המסלול ישלימו את הנקודות החסרות בכלכלה ע"י קורסי בחירה במהלך התואר" 11 נ"ז מקורסי בחירה ו/או ליבה בחוג, 12 נ"ז מכלל הקורסים באוניברסיטה, בכפוף להנחיות המופיעות בשנתון המחלקה, ובאישור יועץ הב"א.
#
#
# הפקולטה למדעי החברה :כלכלה
# Economics as a Social Theory כלכלה כתיאוריה חברתית: ביקורת הכלכלה המדינית
# הקורס אינו מתקיים השנה   |   57642
# מבחן בית 1 ש"ש 2 נ"ז סמסטר א'
# דרישות קדם     תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
#
# הפקולטה למדעי החברה :כלכלה
# Programming in Stata תכנות ב-STATA
# הקורס אינו מתקיים השנה   |   57132
# משך הבחינה: 2.00 ש' בחינה בכתב 1 ש"ש 2 נ"ז סמסטר ב'
# דרישות קדם     תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
#
# הפקולטה למדעי החברה :כלכלה
# ADVANCED MATHEMATICS FOR ECONOMISTS מתמטיקה מתקדמת לכלכלנים   |   57556
# משך הבחינה: 2.50 ש' בחינה בכתב 1.5 ש"ש 3 נ"ז סמסטר ב'
#       תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
# 2203 חבר (הר הצופים)
#
# 13:15-10:30
# יום ג'
# סמסטר ב
# (א) שעור פרופ אלחנן בן-פורת
# הערה:
# אופי הבחינה/המטלה הסופית עשוי להשתנות בהתאם להחלטות אוניברסיטאיות פקולטטיות לרגל המצב. דרישה מוקדמת: ציון עובר בקורסי שנה א' בכלכלה וכן בקורס 'אלגברה ליניארית לכלכלנים' (57509/52323).
# Comments:
# Prerequisite: Passing grade in all first-year economics courses and in Linear Algebra for Economics (57509/52323).
#
# הפקולטה למדעי החברה :כלכלה
# Social Identity and Economic Policy זהות חברתית ומדיניות כלכלית   |   57830
# עבודה בכתב 2 ש"ש 4 נ"ז סמסטר ב'
#       תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
# 4212 חבר - כלכלה
#
#
#
# 16:45-15:00
# 18:15-16:30
# יום ב'
# יום ד'
# סמסטר ב
# סמסטר ב
# (א) שעור פרופ משה שעיו
# הערה:
# הקורס פתוח לתלמידי ב"א, שממוצע ציוניהם בקורסים 'תורת המחירים א', 'תורת המחירים ב' ו'מבוא לאקונומטריקה הוא 90 לפחות.
# Comments:
#
#
# הפקולטה למדעי החברה :כלכלה
# DYNAMIC MODELS FOR ECONOMISTS מודלים דינמיים לכלכלנים   |   57973
# משך הבחינה: 2.00 ש' בחינה בכתב 1.5 ש"ש 3 נ"ז סמסטר א'
# דרישות קדם     תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
#
#
# 19:15-16:30
# יום א'
# סמסטר א
# (א) שעור ד"ר יונתן סטופ
# הערה:
# קורס מ"א פתוח גם לתלמידי ב"א שנה ג'. דרישה מוקדמת: ציון עובר בקורס אלגברה ליניארית לכלכלנים (57509/52323).
# Comments:
# Graduate course also available to third-year undergraduate students. Prerequisite: Passing grade in the courses Linear Algebra for Economics (57509/52323)
#
# ביה"ס למנהל העסקים :מנהל עסקים
# Fundamentals of Finance יסודות המימון   |   55803
# משך הבחינה: 3.00 ש' בחינה בכתב 1.5 ש"ש 3 נ"ז סמסטר א' או/ו ב'
# דרישות קדם קורסים חלופיים   תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
#
# באולם, וגם מועבר ...
# 17:15-14:30
# יום ד'
# סמסטר א
# (א) שעור פרופ אורלי שדה
# 2111 חבר (הר הצופים)
# באולם, וגם מועבר ...
# 15:45-13:00
# יום ב'
# סמסטר א
# (ב) שעור פרופ אורלי שדה
# 2113 חבר (הר הצופים)
#
# 15:45-13:00
# יום ב'
# סמסטר ב
# (ג) שעור פרופ אורלי שדה
# 2113 חבר (הר הצופים)
# בקמפוס
# 19:15-16:30
# יום ג'
# סמסטר ב
# (ד) שעור ד"ר מאיה שטאון
# 1708 חבר (הר הצופים)
#
# 16:45-16:00
# יום ב'
# סמסטר א
# (א) תרג
# 2102 חבר (הר הצופים)
#
# 18:15-17:30
# יום ד'
# סמסטר א
# (ב) תרג
# 2112 חבר (הר הצופים)
#
# 17:45-17:00
# יום ב'
# סמסטר ב
# (ג) תרג
# 2113 חבר (הר הצופים)
#
# 20:15-19:30
# יום ג'
# סמסטר ב
# (ד) תרג
# הערה:
# קדרישה מוקדמת: קורסים מס' 52116 ומס' 55701. בנוסף יש ללמוד לפני או במקביל את קורס מס' 55321. . ציון עובר בקורס הינו 60. לקבלת פטור מקורס מקביל בתואר שני, יש לעבור את הקורס בציון 70. התרגיל הינו רשות
# Comments:
# Prerequisite: Courses no. 52116, 55701. Also course no. 55321 concomitantly The passing grade is 60. In order to get exemption from the equivalent MBA course, the passing grade is 70.
#
# הפקולטה למדעי החברה :כלכלה
# Topics in Fiscal Policy נושאים במדיניות פיסקלית   |   57705
# משך הבחינה: 2.00 ש' בחינה בכתב 1 ש"ש 2 נ"ז סמסטר ב'
# דרישות קדם     תכניות לימודים אתר הקורס סילבוס / Syllabus
# אולם/קמפוס סוג המפגש/מועדים מיוחדים שעה יום בשבוע סמסטר קבוצה סוג שיעור שם המרצה
# 2303 חבר (הר הצופים)
#
# 20:15-18:30
# יום א'
# סמסטר ב
# (א) שעור פרופ מישל סטרבצינסקי
# הערה:
# אופי הבחינה/המטלה הסופית עשוי להשתנות בהתאם להחלטות אוניברסיטאיות פקולטטיות לרגל המצב. דרישה מוקדמת: ציון עובר בקורסים מקרו כלכלה א' (57305), מבוא לאקונומטריקה (57322).
# Comments:
# Prerequisite: Passing grade in the courses Macro-Economics 1 (57305), Introduction to Econometrics (57322).
#
#
#
# הצג תוצאות באופן
#
# מצומצם
#     מפורט
#     מצומצם מאוד
#         עבור מסלול
# חטיבה בסטטיסטיקה- חישוביות סטטיסטית היסקית (חס"ה)
# מתמטיקה סטטיסטיקה ומדע הנתונים במסלול דו חוגי
# סטטיסטיקה ומדע הנתונים בוגר דו-חוגי
# סטטיסטיקה מדע הנתונים בוגר חד חוגי
# סטטיסטיקה מדע הנתונים וכלכלה בוגר דו-חוגי
#
#
# :עבור לדף העמוד הקודם  1   2
